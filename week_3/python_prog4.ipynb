# %% [markdown]
# <a href="https://colab.research.google.com/github/RameswarapuSiddhardha08/python_lab1/blob/main/week_3/python_prog4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.indexing
#2.slicing
#3.concatenating
#4.repetation
#5.memebership operator
#6.iteration

# %%
l1=[1,2,3,55,66,88,99.0,"hello","name"]
l2=[100,220,440]
print(l1+l2)
print(l2*3)
print(l1[5])
print(100 in l2)
print(l1[2:7])
print(l1[::-1])
print(l1[-7:-1])
for i in l2:
  print(i)
# Out:
# [1, 2, 3, 55, 66, 88, 99.0, 'hello', 'name', 100, 220, 440]
# [100, 220, 440, 100, 220, 440, 100, 220, 440]
# 88
# True
# [3, 55, 66, 88, 99.0]
# ['name', 'hello', 99.0, 88, 66, 55, 3, 2, 1]
# [3, 55, 66, 88, 99.0, 'hello']
# 100
# 220
# 440
