# %% [markdown]
# <a href="https://colab.research.google.com/github/RameswarapuSiddhardha08/python_lab1/blob/main/week_1/python_prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("age")
# Out:
# age

# %%
a=2
print(a)
# Out:
# 2

# %%
print("a")
# Out:
# a

# %%
print(2+3.4)
# Out:
# 5.4

# %%
print("2+5")
# Out:
# 2+5

# %%
a=input()
# Out:
# hello

# %%
a
# Out:
# 'hello'

# %%
a=int(input())
# Out:
# 23

# %%
a
# Out:
# 23

# %%
print(2*5)
# Out:
# 10

# %%
print(6/2)
# Out:
# 3.0

# %%
print(6//2)
# Out:
# 3

# %% [markdown]
# arthmetic operations in python
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.normal division  /  ie a/b gives float value as quotient
# 5.floor division  //  ie a//b gives integer as quotient
# 6.modulo division  %  gives remainder
# 7.exponent  **  (a*b) (a power b)
